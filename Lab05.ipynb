# %% [markdown]
# ### LAB05 TỔNG HỢP

# %%
#1. Đọc dữ liệu
import pandas as pd
data = pd.read_csv('winequality-red.csv', sep=';');
print(data.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
#Hiển thị 5 dòng đầu tiên
print(data.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
#Thông tin về dữ liệu
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# None

# %%
#Thống kê mô tả
print(data.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
#2. Phân tích khám phá dữ liệu.
#2.1. Kiểm tra giá trị thiếu.
print(data.isnull().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#2.2. Vẽ histogram cho tất cả các biến và nhận xét.
import matplotlib.pyplot as plt 
data.hist(bins=50, figsize=(20,15)) 
plt.show() 
#Nhận xét:
#- Các biến có phân phối không chuẩn.
#- Các biến có phân phối lệch phải.
#- Các biến có phân phối lệch trái.
#- Các biến có phân phối chuẩn.

# %%
#2.3. Vẽ Boxlot cho tất cả các biến và nhận xét.
data.boxplot(figsize=(20,15))
plt.show()
#Nhận xét:
#- Có nhiều biến có nhiều giá trị ngoại lệ.
#- Có biến có giá trị ngoại lệ ở cả hai phía.
#- Có biến có giá trị ngoại lệ ở phía trên.

# %%
#2.4. Vẽ Scatterplot cho "alcohol" và "quality".
plt.scatter(data['alcohol'], data['quality'])
plt.xlabel('Alcohol')
plt.ylabel('Quality')
plt.title('Alcohol vs Quality')
plt.show()
#Nhận xét:
#- Có mối tương quan giữa alcohol và quality.
#- Khi alcohol tăng thì quality cũng tăng.
#- Có một số điểm dữ liệu nằm xa so với các điểm dữ liệu còn lại.

# %%
#3. Tính toán ma trận tương quan và vẽ heatmap của ma trận tương quan đó.
import seaborn as sns
corr = data.corr() 
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f') 
plt.show()

# %%
#4. Chia tập dữ liệu thủ công không dùng thư viện có sẵn
#4.1. Xáo trộn dữ liệu
import numpy as np
np.random.seed(42)
data = np.random.permutation(data)
print(data)
# Out:
# [[ 7.7   0.56  0.08 ...  0.66  9.6   6.  ]
#  [ 7.8   0.5   0.17 ...  0.48  9.5   5.  ]
#  [10.7   0.67  0.22 ...  0.98  9.9   6.  ]
#  ...
#  [ 7.2   0.62  0.06 ...  0.54  9.5   5.  ]
#  [ 7.9   0.2   0.35 ...  0.8  11.9   7.  ]
#  [ 5.8   0.29  0.26 ...  0.54 13.5   6.  ]]

# %%
#4.2. Chia dữ liệu với 80% huấn luyện
train_size = 0.8 
train_data = data[:int(train_size*len(data))]
test_data = data[int(train_size*len(data)):]
print(train_data)
print(test_data)
# Out:
# [[ 7.7   0.56  0.08 ...  0.66  9.6   6.  ]
#  [ 7.8   0.5   0.17 ...  0.48  9.5   5.  ]
#  [10.7   0.67  0.22 ...  0.98  9.9   6.  ]
#  ...
#  [ 5.6   0.31  0.78 ...  0.48 10.5   6.  ]
#  [ 7.5   0.55  0.24 ...  0.78  9.5   6.  ]
#  [ 7.2   0.52  0.07 ...  0.81  9.6   6.  ]]
# [[ 8.    0.28  0.44 ...  0.66 11.2   5.  ]
#  [ 7.    0.5   0.14 ...  0.61 10.4   5.  ]
#  [ 6.    0.5   0.   ...  0.45  9.5   5.  ]
#  ...
#  [ 7.2   0.62  0.06 ...  0.54  9.5   5.  ]
#  [ 7.9   0.2   0.35 ...  0.8  11.9   7.  ]
#  [ 5.8   0.29  0.26 ...  0.54 13.5   6.  ]]

# %%
#4.3. Tách dữ liệu
train_df = pd.DataFrame(train_data, columns=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality'])
test_df = pd.DataFrame(test_data, columns=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality'])

X_train = train_df.drop('quality', axis=1)
y_train = train_df['quality']
X_test = test_df.drop('quality', axis=1)
y_test = test_df['quality']
print (X_train)
print (y_train)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.7              0.56         0.08            2.50      0.114
# 1               7.8              0.50         0.17            1.60      0.082
# 2              10.7              0.67         0.22            2.70      0.107
# 3               8.5              0.46         0.31            2.25      0.078
# 4               6.7              0.46         0.24            1.70      0.077
# ...             ...               ...          ...             ...        ...
# 1274            8.5              0.28         0.56            1.80      0.092
# 1275            7.2              0.35         0.26            1.80      0.083
# 1276            5.6              0.31         0.78           13.90      0.074
# 1277            7.5              0.55         0.24            2.00      0.078
# 1278            7.2              0.52         0.07            1.40      0.074
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    14.0                  46.0  0.99710  3.24       0.66
# 1                    21.0                 102.0  0.99600  3.39       0.48
# 2                    17.0                  34.0  1.00040  3.28       0.98
# 3                    32.0                  58.0  0.99800  3.33       0.54
# 4                    18.0                  34.0  0.99480  3.39       0.60
# ...                   ...                   ...      ...   ...        ...
# 1274                 35.0                 103.0  0.99690  3.30       0.75
# 1275                 33.0                  75.0  0.99680  3.40       0.58
# 1276                 23.0                  92.0  0.99677  3.39       0.48
# 1277                 10.0                  28.0  0.99830  3.45       0.78
# 1278                  5.0                  20.0  0.99730  3.32       0.81
#
#       alcohol
# 0         9.6
# 1         9.5
# 2         9.9
# 3         9.8
# 4        10.6
# ...       ...
# 1274     10.5
# 1275      9.5
# 1276     10.5
# 1277      9.5
# 1278      9.6
#
# [1279 rows x 11 columns]
# 0       6.0
# 1       5.0
# 2       6.0
# 3       5.0
# 4       6.0
#        ...
# 1274    7.0
# 1275    6.0
# 1276    6.0
# 1277    6.0
# 1278    6.0
# Name: quality, Length: 1279, dtype: float64

# %%
#4.4. Tách đặc trưng và nhãn.
X = train_df.drop('quality', axis=1)
y = train_df['quality']
print(X)
print(y)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.7              0.56         0.08            2.50      0.114
# 1               7.8              0.50         0.17            1.60      0.082
# 2              10.7              0.67         0.22            2.70      0.107
# 3               8.5              0.46         0.31            2.25      0.078
# 4               6.7              0.46         0.24            1.70      0.077
# ...             ...               ...          ...             ...        ...
# 1274            8.5              0.28         0.56            1.80      0.092
# 1275            7.2              0.35         0.26            1.80      0.083
# 1276            5.6              0.31         0.78           13.90      0.074
# 1277            7.5              0.55         0.24            2.00      0.078
# 1278            7.2              0.52         0.07            1.40      0.074
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    14.0                  46.0  0.99710  3.24       0.66
# 1                    21.0                 102.0  0.99600  3.39       0.48
# 2                    17.0                  34.0  1.00040  3.28       0.98
# 3                    32.0                  58.0  0.99800  3.33       0.54
# 4                    18.0                  34.0  0.99480  3.39       0.60
# ...                   ...                   ...      ...   ...        ...
# 1274                 35.0                 103.0  0.99690  3.30       0.75
# 1275                 33.0                  75.0  0.99680  3.40       0.58
# 1276                 23.0                  92.0  0.99677  3.39       0.48
# 1277                 10.0                  28.0  0.99830  3.45       0.78
# 1278                  5.0                  20.0  0.99730  3.32       0.81
#
#       alcohol
# 0         9.6
# 1         9.5
# 2         9.9
# 3         9.8
# 4        10.6
# ...       ...
# 1274     10.5
# 1275      9.5
# 1276     10.5
# 1277      9.5
# 1278      9.6
#
# [1279 rows x 11 columns]
# 0       6.0
# 1       5.0
# 2       6.0
# 3       5.0
# 4       6.0
#        ...
# 1274    7.0
# 1275    6.0
# 1276    6.0
# 1277    6.0
# 1278    6.0
# Name: quality, Length: 1279, dtype: float64

# %%
#5. Chuẩn bị dữ liệu
from sklearn.preprocessing import StandardScaler
#5.1. Khổi tạo bộ dữ liệu chuẩn hóa.
scaler = StandardScaler()

# %%
#5.2. Chuẩn hóa huấn luyện.
X_train = scaler.fit_transform(X_train)
print (X_train)
# Out:
# [[-0.35592521  0.18348583 -0.99124445 ... -0.45482449  0.016453
#   -0.74610822]
#  [-0.29887905 -0.14931262 -0.52157232 ...  0.51170274 -1.07513483
#   -0.83975462]
#  [ 1.35545955  0.79361632 -0.26064335 ... -0.19708389  1.9570536
#   -0.46516902]
#  ...
#  [-1.55389454 -1.20317438  2.66176106 ...  0.51170274 -1.07513483
#    0.09670937]
#  [-0.47001753  0.12801942 -0.15627177 ...  0.89831363  0.74417822
#   -0.83975462]
#  [-0.641156   -0.03837981 -1.04343025 ...  0.0606567   0.92610953
#   -0.74610822]]

# %%
#5.3. Chuẩn hóa kiểm tra.
X_test = scaler.transform(X_test)
print (X_test)
# Out:
# [[-0.18478674 -1.36957361  0.8874441  ...  0.31839729  0.016453
#    0.75223416]
#  [-0.75524832 -0.14931262 -0.6781297  ...  1.41379481 -0.28676584
#    0.00306297]
#  [-1.32570991 -0.14931262 -1.4087308  ...  0.31839729 -1.25706614
#   -0.83975462]
#  ...
#  [-0.641156    0.51628428 -1.09561604 ...  1.28492451 -0.71127222
#   -0.83975462]
#  [-0.24183289 -1.81330488  0.41777196 ...  0.0606567   0.86546576
#    1.40775896]
#  [-1.43980223 -1.3141072  -0.05190018 ...  0.51170274 -0.71127222
#    2.90610134]]

# %%
#6. Ứng dụng mô hình hồi quy tuyến tính
from sklearn.linear_model import LinearRegression
#6.1. Khởi tạo
model = LinearRegression()

# %%
#6.2. Huấn luyện.
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#6.3. Dự đoán trên tập kiểm tra.
y_pred = model.predict(X_test)
print(y_pred)
# Out:
# [6.05848455 5.5490091  5.3496577  5.42258039 5.88654498 5.80860231
#  6.2372499  5.68250608 5.54588515 6.05591423 5.42657825 5.56140581
#  5.79361235 5.40753322 6.0955014  5.35926577 5.66583513 6.3678573
#  5.25827583 4.97734456 6.6476064  5.79070285 5.94733943 6.24722512
#  5.17708127 5.85118564 5.94925218 5.0493944  5.06988878 6.03374223
#  5.72994321 6.7071302  5.22706743 5.8833526  6.33099304 5.22360913
#  5.46202077 6.34901707 6.27309794 5.72813487 5.89361752 5.07026253
#  6.33585059 5.88654498 5.90766297 5.29734881 5.96868303 5.62614343
#  5.10737807 5.00101202 6.34544835 6.18143496 5.00481429 5.33591846
#  5.84442459 5.7864948  6.00778817 5.44698913 4.9461761  5.74033579
#  6.58583973 5.57087106 5.51625395 5.92332714 6.33339968 5.39887117
#  5.54725966 5.50548676 5.62582725 5.744059   5.98429985 5.2742779
#  5.40511986 5.05073382 5.39778383 6.28171785 6.16671682 5.41001977
#  5.75136425 4.98965143 5.70372758 6.1140404  5.06727263 5.42840867
#  4.8351441  5.6048943  5.20916557 6.15430442 6.09795626 5.28787819
#  5.49609584 5.20779158 5.28141429 6.26828216 4.95655421 5.80860231
#  5.62807955 5.44558145 4.99800996 4.97778452 5.49018637 5.5512079
#  5.08104188 5.07799309 4.88347177 5.14701622 6.03515146 5.31781053
#  6.48952937 5.9950225  5.03572037 5.1364827  5.20479984 5.29357968
#  5.11273075 5.76587627 6.49802    5.81838312 5.81395493 5.67516042
#  6.20410251 6.1376288  5.27695169 5.14306685 6.24529682 5.58077473
#  5.70761942 5.47517063 5.36764659 5.98549602 5.80552658 5.13050543
#  5.64217491 6.19054433 5.0237524  5.73941522 5.22969796 5.00481429
#  6.94057831 6.05858413 4.98066041 5.67592077 6.2922357  5.39145957
#  5.98890099 5.22572449 5.78099212 5.48056922 4.96831435 6.02445606
#  5.61776938 5.17405005 5.78939622 5.54734882 5.16947107 5.27906734
#  6.19413478 5.38036126 5.07430167 5.42182974 6.61998823 5.73239639
#  6.66811586 5.71894624 6.14631904 5.6949609  6.28265427 5.23547239
#  4.98871029 4.9658584  6.6291172  6.10741547 5.48121472 6.49991902
#  5.8833526  5.7535516  5.18624991 5.20224686 5.6565606  5.66245465
#  5.2742779  5.47478075 6.28997026 5.50980592 5.61787282 5.08205331
#  5.51388292 5.91637041 6.43438392 4.97958668 6.19413478 6.48903727
#  5.18393369 6.11305217 5.05241934 5.57220667 5.7539485  6.68563009
#  5.90286529 6.80318505 5.88564654 5.86129877 5.88754173 5.29047913
#  6.5088394  6.23068723 5.5320535  5.33376123 5.93547    5.97146096
#  5.36951437 5.1851458  6.14696179 5.91870725 6.93831135 5.83776661
#  5.10605777 5.069192   5.69912644 4.98981397 6.39060443 5.33502032
#  5.70686092 5.08176474 5.56189645 6.59580235 5.02890294 5.25627113
#  6.47751901 5.96473293 5.93176711 6.17517677 5.45483572 5.74133407
#  5.77989634 5.66210516 5.95186823 5.26353084 5.27302699 5.79422339
#  5.90001826 5.74246572 6.14631904 5.28545897 5.72859829 6.39372736
#  6.10741547 5.29570331 4.88148915 5.52946716 6.11458772 5.14150665
#  6.01994559 6.14892913 6.70152382 4.95323446 5.62578926 6.2296651
#  5.43125888 4.9208397  6.05029147 6.08519667 5.86792215 5.05449112
#  5.21467974 6.18523596 5.15856635 6.36233906 5.49609734 5.3595703
#  5.9969234  5.81002374 5.72681348 5.8563032  6.4755337  5.25111984
#  5.42657825 5.06004199 5.86801979 5.04442684 5.25050604 6.02090765
#  5.78190354 5.70713843 5.39472598 5.93333878 5.9950225  5.29144697
#  5.80763324 5.35488241 5.3496577  5.07308099 5.41281727 5.38326703
#  5.9442418  6.14657337 5.36902248 6.73290522 5.27993394 4.88795821
#  5.68295845 5.11622823 5.57788583 4.86902752 5.56114202 6.17487181
#  5.32273318 5.45277257 5.44081024 6.30423677 5.0638402  6.13432042
#  5.68476039 6.2760978  5.75732445 5.76879779 5.81395493 4.93507181
#  6.64255851 6.71036757]

# %%
#7. Đánh giá mô hình
from sklearn.metrics import mean_squared_error, r2_score

#Tính MSE và R^2.
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print ('Mean Squared Error:', mse)
print ('R^2:', r2)
# Out:
# Mean Squared Error: 0.350081785985065
# R^2: 0.4223966408083485

# %%
#Bài tập về nhà:
#1. Hoàn thành bài tập trên sao cho đoạn code có thể chạy mượt mà và chính xác.
#2. Cho bộ dữ liệu sau: How long we live 
#2.1. Đọc dữ liệu.
data = pd.read_csv('howlongwelive.csv')
print(data.head())
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
#2.2. Tôi muốn biết có bao nhiêu cột và bao nhiêu hàng.
print(data.shape)
# Out:
# (2938, 22)

# %%
#2.3. Tôi muốn biết danh sách tên của các cột, danh sách của các hàng.
print(data.columns)
print(data.index)
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')
# RangeIndex(start=0, stop=2938, step=1)

# %%
#2.4. Thử dùng df["status"].
data = pd.read_csv('howlongwelive.csv')
try:
    print(data["Status"])
except KeyError:
    print("Cột 'status' không tồn tại trong DataFrame.")
# Out:
# 0       Developing
# 1       Developing
# 2       Developing
# 3       Developing
# 4       Developing
#            ...
# 2933    Developing
# 2934    Developing
# 2935    Developing
# 2936    Developing
# 2937    Developing
# Name: Status, Length: 2938, dtype: object

# %%
#2.5. Tính số lượng các nước đang phát triển và các nước phát triển.
try:
    print(data['Status'].value_counts())
    print(data['Status'].value_counts(normalize=True))
except KeyError:
    print("Cột 'status' không tồn tại trong DataFrame.")
# Out:
# Status
# Developing    2426
# Developed      512
# Name: count, dtype: int64
# Status
# Developing    0.825732
# Developed     0.174268
# Name: proportion, dtype: float64

# %%
#2.6. Tính min, max, mean, median của alcohol.
try:
    min_alcohol = data['alcohol'].min()
    max_alcohol = data['alcohol'].max()
    mean_alcohol = data['alcohol'].mean()
    median_alcohol = data['alcohol'].median()
    
    print(f"Min: {min_alcohol}")
    print(f"Max: {max_alcohol}")
    print(f"Mean: {mean_alcohol}")
    print(f"Median: {median_alcohol}")
except KeyError:
    print("Cột 'alcohol' không tồn tại trong DataFrame.")
# Out:
# Min: 8.4
# Max: 14.9
# Mean: 10.422983114446529
# Median: 10.2

# %%
#Bài 1: Đếm những hàng có rượu nhiều hơn mức trung bình và liệt kê các quốc gia độc đáo này.
#2.6.1. Tính mức trung bình của alcohol.
data = pd.read_csv('winequality-red.csv', sep=';')  
mean_alcohol = data['alcohol'].mean()
print(f"Mức trung bình của alcohol: {mean_alcohol}")
# Out:
# Mức trung bình của alcohol: 10.422983114446529

# %%
#2.6.2. Lọc ra những hàng có alcohol lớn hơn mức trung bình.
data = pd.read_csv('winequality-red.csv', sep=';')  
high_alcohol_count = data[data['alcohol'] > mean_alcohol].shape[0]
print(f"Số hàng có rượu nhiều hơn mức trung bình: {high_alcohol_count}")
# Out:
# Số hàng có rượu nhiều hơn mức trung bình: 683

# %%
#2.6.3. Liệt kê các quốc gia độc đáo.
data = pd.read_csv('winequality-red.csv', sep=';')
mean_alcohol = data['alcohol'].mean()
high_alcohol_wines = data[data['alcohol'] > mean_alcohol]
print(f"Số lượng mẫu rượu có nồng độ alcohol cao hơn mức trung bình: {len(high_alcohol_wines)}")
print(high_alcohol_wines[['alcohol', 'quality']].head())
# Out:
# Số lượng mẫu rượu có nồng độ alcohol cao hơn mức trung bình: 683
#     alcohol  quality
# 9      10.5        5
# 11     10.5        5
# 16     10.5        7
# 31     10.6        6
# 36     10.8        6

# %%
#Bài 2: Lấy danh sách quốc gia có trình độ học vấn cao hơn mức trung bình và GDP cao hơn mức trung bình.
#2.6.1. Tính mức trung bình của schooling và GDP.
data = pd.read_csv('howlongwelive.csv')
mean_schooling = data['Schooling'].mean()
mean_gdp = data['GDP'].mean()
print(mean_schooling)
print(mean_gdp)
# Out:
# 11.992792792792793
# 7483.158469138474

# %%
#2.6.2. Lọc ra những hàng có schooling và GDP lớn hơn mức trung bình.
data_schooling = data[data['Schooling'] > mean_schooling]
data_gdp = data[data['GDP'] > mean_gdp]
print(data_schooling)
print(data_gdp)
# Out:
#       Country  Year      Status  Life expectancy   Adult Mortality  \
# 16    Albania  2015  Developing              77.8             74.0
# 17    Albania  2014  Developing              77.5              8.0
# 18    Albania  2013  Developing              77.2             84.0
# 19    Albania  2012  Developing              76.9             86.0
# 20    Albania  2011  Developing              76.6             88.0
# ...       ...   ...         ...               ...              ...
# 2906   Zambia  2015  Developing              61.8             33.0
# 2907   Zambia  2014  Developing              61.1            314.0
# 2908   Zambia  2013  Developing              63.0            328.0
# 2909   Zambia  2012  Developing              59.2            349.0
# 2910   Zambia  2011  Developing              58.2            366.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 16                0     4.60              364.975229         99.0         0
# 17                0     4.51              428.749067         98.0         0
# 18                0     4.76              430.876979         99.0         0
# 19                0     5.14              412.443356         99.0         9
# 20                0     5.37              437.062100         99.0        28
# ...             ...      ...                     ...          ...       ...
# 2906             27      NaN                0.000000          9.0         9
# 2907             28     0.01              196.667577         86.0         9
# 2908             29     2.41               20.623063         79.0        35
# 2909             29     2.59              196.915250         78.0       896
# 2910             29     2.57              183.046169         81.0     13234
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS          GDP  \
# 16    ...   99.0               6.00         99.0        0.1  3954.227830
# 17    ...   98.0               5.88         98.0        0.1  4575.763787
# 18    ...   99.0               5.66         99.0        0.1  4414.723140
# 19    ...   99.0               5.59         99.0        0.1  4247.614380
# 20    ...   99.0               5.71         99.0        0.1  4437.178680
# ...   ...    ...                ...          ...        ...          ...
# 2906  ...    9.0                NaN          9.0        4.1  1313.889646
# 2907  ...   78.0               4.99         86.0        4.3  1738.882200
# 2908  ...   74.0               4.99         79.0        4.8   185.793359
# 2909  ...    7.0               4.91         78.0        5.6  1734.936120
# 2910  ...   83.0               4.26         81.0        6.3  1644.619672
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 16       28873.0                    1.2                  1.3
# 17      288914.0                    1.2                  1.3
# 18      289592.0                    1.3                  1.4
# 19        2941.0                    1.3                  1.4
# 20      295195.0                    1.4                  1.5
# ...          ...                    ...                  ...
# 2906    161587.0                    6.3                  6.1
# 2907   1562974.0                    6.3                  6.2
# 2908   1515321.0                    6.4                  6.2
# 2909  14699937.0                    6.5                  6.3
# 2910  14264756.0                    6.6                  6.4
#
#       Income composition of resources  Schooling
# 16                              0.762       14.2
# 17                              0.761       14.2
# 18                              0.759       14.2
# 19                              0.752       14.2
# 20                              0.738       13.3
# ...                               ...        ...
# 2906                            0.576       12.5
# 2907                            0.570       12.5
# 2908                            0.565       12.5
# 2909                            0.554       12.3
# 2910                            0.543       12.0
#
# [1527 rows x 22 columns]
#                   Country  Year      Status  Life expectancy   \
# 64    Antigua and Barbuda  2015  Developing              76.4
# 65    Antigua and Barbuda  2014  Developing              76.2
# 66    Antigua and Barbuda  2013  Developing              76.1
# 67    Antigua and Barbuda  2012  Developing              75.9
# 68    Antigua and Barbuda  2011  Developing              75.7
# ...                   ...   ...         ...               ...
# 2811              Uruguay  2014  Developing              76.8
# 2812              Uruguay  2013  Developing              76.8
# 2814              Uruguay  2011  Developing              77.0
# 2815              Uruguay  2010  Developing              76.3
# 2816              Uruguay  2009  Developing              76.6
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 64               13.0              0      NaN                0.000000
# 65              131.0              0     8.56             2422.999774
# 66              133.0              0     8.58             1991.430372
# 67              134.0              0     8.18             2156.229842
# 68              136.0              0     7.84             1810.875316
# ...               ...            ...      ...                     ...
# 2811            117.0              0     6.03              463.639782
# 2812            117.0              0     5.82              482.803945
# 2814            111.0              0     5.97              417.911744
# 2815            118.0              0     6.21             2331.532804
# 2816            118.0              0     6.67             1871.736563
#
#       Hepatitis B  Measles   ...  Polio  Total expenditure  Diphtheria   \
# 64           99.0         0  ...   86.0                NaN         99.0
# 65           99.0         0  ...   96.0               5.54         99.0
# 66           99.0         0  ...   98.0               5.33         99.0
# 67           98.0         0  ...   97.0               5.39         98.0
# 68           99.0         0  ...   99.0               5.65         99.0
# ...           ...       ...  ...    ...                ...          ...
# 2811         95.0         0  ...   95.0               8.58         95.0
# 2812         94.0         0  ...   94.0               8.68         94.0
# 2814         95.0         0  ...   95.0               8.55         95.0
# 2815         95.0         0  ...   95.0               8.63         95.0
# 2816         95.0         0  ...   95.0               8.78         95.0
#
#        HIV/AIDS          GDP  Population   thinness  1-19 years  \
# 64          0.2  13566.95410         NaN                    3.3
# 65          0.2  12888.29667         NaN                    3.3
# 66          0.2  12224.86416         NaN                    3.3
# 67          0.2  12565.44197         NaN                    3.3
# 68          0.1  11929.34991         NaN                    3.3
# ...         ...          ...         ...                    ...
# 2811        0.1  16737.89827   3419546.0                    1.5
# 2812        0.1  16881.25680      3485.0                    1.5
# 2814        0.1  14166.49980   3385624.0                    1.5
# 2815        0.1  11938.21200   3374415.0                    1.5
# 2816        0.1   9415.17386   3362755.0                    1.5
#
#        thinness 5-9 years  Income composition of resources  Schooling
# 64                    3.3                            0.784       13.9
# 65                    3.3                            0.782       13.9
# 66                    3.3                            0.781       13.9
# 67                    3.3                            0.778       13.8
# 68                    3.3                            0.782       14.1
# ...                   ...                              ...        ...
# 2811                  1.4                            0.791       15.5
# 2812                  1.4                            0.788       15.5
# 2814                  1.5                            0.780       15.5
# 2815                  1.5                            0.777       15.6
# 2816                  1.5                            0.774       15.5
#
# [540 rows x 22 columns]
